# %%
## create a new directory
import os


new_directory = "package"
os.mkdir(new_directory)
print(f"Diractory '{new_directory}' created.")
# Out:
# Diractory 'package' created.

# %%
## Listing files and directories
items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileoperation.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
### Joining paths

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# e:\Python1.0\6-File Handling\folder\file.txt

# %%
path='example1.txt'

if os.path.exists(path):
    print(f"'{path}' exists.")
else:
    print(f"'{path}' does not exist.")
# Out:
# 'example1.txt' does not exist.

# %%
# Checking if a path is a file or directory

path = 'example1.txt'
if os.path.isfile(path):
    print(f"'{path}' is a file")
elif os.path.isdir(path):
    print(f"'{path}' is a directory")
else:
    print(f"'{path}' is neither a file nor a directory")
# Out:
# 'example1.txt' is neither a file nor a directory

# %%
## Getting the absolute path of a file
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(f"absolute path: {absolute_path}")
# Out:
# absolute path: e:\Python1.0\6-File Handling\example.txt
