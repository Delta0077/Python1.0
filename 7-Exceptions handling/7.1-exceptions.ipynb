# %%
## Understanding Exceptions
### What is an Exception?
## An exception is an error that occurs during the execution of a program. When an exception occurs,the normal flow of the program is interrupted, and the program may terminate if the exception is not handled properly. Exceptions can occur for various reasons, such as invalid input, file not found, division by zero, etc. 

## What are the common types of exceptions in Python?
## 1. **SyntaxError**: Raised when there is a syntax error in the code.
## 2. **TypeError**: Raised when an operation or function is applied to an object of inappropriate type.
## 3. **ValueError**: Raised when a built-in operation or function receives an argument that has the right type but an inappropriate value.
## 4. **FileNotFoundError**: Raised when trying to open a file that does not exist.
## 5. **ZeroDivisionError**: Raised when the second argument of a division or modulo operation is zero.
## 6. **IndexError**: Raised when trying to access an index that is out of range in a list or tuple.
## 7. **KeyError**: Raised when trying to access a key that does not exist in a dictionary.
## 8. **AttributeError**: Raised when an attribute reference or assignment fails.
## 9. **ImportError**: Raised when an import statement fails to find the module definition or when a from ... import fails to find a name that is to be imported.
## 10. **NameError**: Raised when a local or global name is not found.

# %%
## Exception try and except blocks

try:
    a=b
except:
    print("The variable has not been assigned.")
# Out:
# The variable has not been assigned.

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
res = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 res = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    res = 1 / 0
    print(res)
except ZeroDivisionError as ex:
    print(ex)
    print("Cannot divide by zero, please provide a non-zero denominator.")
# Out:
# division by zero
# Cannot divide by zero, please provide a non-zero denominator.

# %%
try:
    res = 1 / 2
    a=b
    print(res)
except ZeroDivisionError as ex:
    print(ex)
    print("Cannot divide by zero, please provide a non-zero denominator.")
except Exception as ex1: ## Exception is the base class of all exceptions, it will catch any exception that is not caught by the previous except blocks. This base class we have to write it after all the specific exception blocks, otherwise it will catch all exceptions and the specific exception blocks will never be executed.
    print(ex1)
    print('Main eception got caught here')
# Out:
# name 'b' is not defined
# Main eception got caught here

# %%
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than zero")

except Exception as ex:
    print(ex)
# Out:
# This is not a valid number

# %%
## try, except, else block
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You can't divide by zero")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
# Out:
# You can't divide by zero

# %%
### try,except,else and finally
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
finally:
    print("Execution complete.")
# Out:
# The result is 5.0
# Execution complete.

# %%
### File handling and Exception Handling

try:
    file=open('example1.txt', 'r')
    content = file.read()
    print(content)

except FileNotFoundError:
    print("The file doesn't exist.")

except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file closed')
# Out:
# file closed
