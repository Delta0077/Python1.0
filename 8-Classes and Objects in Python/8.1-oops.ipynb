# %% [markdown]
# ## Classes and Objects

# %%
## A class is a blueprint for creating objects. Attributes,Methods

class Car:
    pass

Audi = Car()
BMW = Car()

print(type(BMW))
# Out:
# <class '__main__.Car'>

# %%
print(Audi)
print(BMW)

# %%
Audi.windows = 4
print(Audi.windows)
# Out:
# 4

# %%
## Instance variables and Methods
tata = Car()
tata.doors = 4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       2 tata = Car()
#       4 tata.doors = 4
# ----> 6 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
class Dog:
    ## Constructor
    def __init__(self, name, age):
        self.name=name
        self.age=age

## Create the objects

dog1=Dog("Nongra Jinis", 8)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Nongra Jinis
# 8

# %%
## Instance Methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self): ## Instance Method
        print(f"{self.name} says woof")
dog1=Dog("Buddy",3)
dog1.bark()

dog2=Dog("Lucy", 4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
### Modelling a Bank account

## Define a class for bank account
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance=balance
    def deposit(self, amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if amount>self.balance:
            print(f"You dont have enough balance to withdraw.")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn from your account. Available balance is: {self.balance}")
    def get_balance(self):
        return self.balance

## Create an account object

account=BankAccount("Aditya", 50000)
print(account.balance)
# Out:
# 50000

# %%
## Call instance methods
account.deposit(10000)
# Out:
# 10000 is deposited. New balance is 60000

# %%
account.withdraw(70000)
# Out:
# You dont have enough balance to withdraw.

# %%
account.withdraw(55000)
# Out:
# 55000 is withdrawn from your account. Available balance is: 5000

# %%
account.get_balance()
# Out:
# 5000

# %%
## Online account

class AccountDetails:
    def __init__(self, name, phone):
        self.name=name
        self.phone=phone
    
    def customerAddress(self,address):
        self.address=address
    def subscription(self,free, premium):
        self.free = free
        self.premium = premium
