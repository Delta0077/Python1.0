# %%
'''
    __init__ : This method is called when an object is created. It is used to initialize the object's attributes.
    __str__ : This method is called when the object is printed. It is used to return a string representation of the object.
    __repr__ : This method is called when the object is printed in the console. It is used to return a string representation of the object that can be used to recreate the object.
    __len__ : This method is called when the len() function is called on the object. It is used to return the length of the object.
    __getitem__ : This method is called when an item is accessed using the indexing operator []. It is used to return the value of the item at the specified index.
    __setitem__ : This method is called when an item is set using the indexing operator []. It is used to set the value of the item at the specified index.
    
'''

# %% [markdown]
# ### Magic Methods

# %%
## Basic Methods
class Person:
    def __init__(self,name, age):
        self.name=name
        self.age=age
person=Person('Aditya', 30)
print(person.name)
# Out:
# Aditya

# %%
## Basic Methods
class Person:
    def __init__(self,name, age):
        self.name=name
        self.age=age
    def __str__(self):
        return f"{self.name} is {self.age} years old"
person=Person('Aditya', 30)
print(person)
# Out:
# Aditya is 30 years old
