# %% [markdown]
# ## Polymorphism

# %% [markdown]
# https://www.geeksforgeeks.org/python/polymorphism-in-python/#:~:text=Polymorphism%20in%20Python,the%20payment%20type.

# %% [markdown]
# ## Method Overriding
#
# https://www.geeksforgeeks.org/python/polymorphism-in-python/#:~:text=Runtime%20Polymorphism%20(Overriding)

# %%
# Base Class
class Animal:
    def speak(self):
        return "Sound of the animal."
## Derived class 1

class Dog(Animal):
    def speak(self):
        return "Woof"
class Cat(Animal):
    def speak(self):
        return "Meow"

## Functions that demonstrates Polymorphism
def animal_speak(animal):
    print(animal.speak())

dog=Dog()
print(dog.speak())
cat=Cat()
print(cat.speak())
animal_speak(dog)
# Out:
# Woof
# Meow
# Woof

# %%
## Polymorphism with Functions and Methods
## base class

class Shape:
    def area(self):
        return "The area of the figure."
## Derived class 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width=width
        self.height=height
    
    def area(self):
        return self.width * self.height
        
## Derived class 2

class Circle(Shape):
    def __init__(self,radius): 
        self.radius=radius

    def area(self):
        return 3.14*self.radius * self.radius
    
## Function that demonstrate polymorphism
def print_area(shape):
    print(f"the area is:{shape.area()}")

rectangle=Rectangle(5,4)
circle=Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# the area is:20
# the area is:28.259999999999998

# %%
## Polymorphism with Abstract Base Class

from abc import ABC,abstractmethod

## Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started."
    
## Derived class 2

class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motor engine started."

## Function that demonstrates Polymorphism
def start_vehicle(vehicle):
    print(vehicle.start_engine())

## Create objects
car=Car()
motorcycle=Motorcycle()

start_vehicle(car)
# Out:
# Car engine started.
